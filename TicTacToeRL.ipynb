# %%
import gym
import gym_tictactoe

env = gym.make("tictactoe-v0")

for e in range(3):
    env.reset()
    print("#######")
    print("Episode: ", e)
    print("#######")
    
    for t in range(9):
        env.render()
        action = t
        state, reward, done, info = env.step(action)
        print("Reward: ", reward)
        print("")
    #end
#end
# Out:
# #######
# Episode:  0
# #######
# - - -
# - - -
# - - -
# Reward:  0
#
# o - -
# - - -
# - - -
# Reward:  0
#
# o x -
# - - -
# - - -
# Reward:  0
#
# o x o
# - - -
# - - -
# Reward:  0
#
# o x o
# x - -
# - - -
# Reward:  0
#
# o x o
# x o -
# - - -
# Reward:  0
#
# o x o
# x o x
# - - -
# Player 1 wins.
# Reward:  100
#
# o x o
# x o x
# o - -
# Game Over
# Reward:  100
#
# o x o
# x o x
# o - -
# Game Over
# Reward:  100
#
# #######
# Episode:  1
# #######
# - - -
# - - -
# - - -
# Reward:  0
#
# o - -
# - - -
# - - -
# Reward:  0
#
# o x -
# - - -
# - - -
# Reward:  0
#
# o x o
# - - -
# - - -
# Reward:  0
#
# o x o
# x - -
# - - -
# Reward:  0
#
# o x o
# x o -
# - - -
# Reward:  0
#
# o x o
# x o x
# - - -
# Player 1 wins.
# Reward:  100
#
# o x o
# x o x
# o - -
# Game Over
# Reward:  100
#
# o x o
# x o x
# o - -
# Game Over
# Reward:  100
#
# #######
# Episode:  2
# #######
# - - -
# - - -
# - - -
# Reward:  0
#
# o - -
# - - -
# - - -
# Reward:  0
#
# o x -
# - - -
# - - -
# ...
